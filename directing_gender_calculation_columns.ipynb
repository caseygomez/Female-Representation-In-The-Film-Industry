# %%
# Import dependencies and files
import pandas as pd

# %%
# Import csv file as dataframe
df = pd.read_csv("Resources/dept_directing.csv")

df
# Out:
#        movie_id department  gender                 job                 name
# 0           949  Directing     1.0   Script Supervisor         Cate Hardman
# 1         11860  Directing     1.0   Script Supervisor        Mary A. Kelly
# 2             5  Directing     1.0            Director       Allison Anders
# 3          9263  Directing     1.0            Director  Lesli Linka Glatter
# 4           687  Directing     1.0   Script Supervisor       Eva Z. Cabrera
# ...         ...        ...     ...                 ...                  ...
# 32178     54400  Directing     0.0            Director          David Blair
# 32179     17630  Directing     0.0            Director        Allan Mauduit
# 32180    154371  Directing     0.0            Director  Hollingsworth Morse
# 32181    180850  Directing     0.0            Director        Robert Nathan
# 32182     16266  Directing     0.0  Assistant Director         Justin Jones
#
# [32183 rows x 5 columns]

# %%
# sort data by movie_id
sorted_df=df.sort_values("movie_id")

sorted_df
# Out:
#        movie_id department  gender                       job  \
# 3249          5  Directing     0.0  First Assistant Director
# 3247          5  Directing     0.0                  Director
# 2             5  Directing     1.0                  Director
# 3246          5  Directing     0.0                  Director
# 3248          5  Directing     0.0                  Director
# ...         ...        ...     ...                       ...
# 20844    462788  Directing     0.0                  Director
# 31713    463800  Directing     0.0                  Director
# 31805    464111  Directing     0.0                  Director
# 31830    467731  Directing     0.0                  Director
# 19005    469172  Directing     0.0                  Director
#
#                       name
# 3249   Douglas Aarniokoski
# 3247      Robert Rodriguez
# 2           Allison Anders
# 3246    Alexandre Rockwell
# 3248     Quentin Tarantino
# ...                    ...
# 20844          Paul Bogart
# 31713       Neill Blomkamp
# 31805       Neill Blomkamp
# 31830         Sidney Lumet
# 19005            Raúl Ruiz
#
# [32183 rows x 5 columns]

# %%
# create df to sum the gender column by movie_id
sum_gender = sorted_df.groupby(["movie_id"]).sum()

sum_gender
# Out:
#           gender
# movie_id
# 5            1.0
# 6            0.0
# 11           0.0
# 12           0.0
# 13           0.0
# ...          ...
# 462788       0.0
# 463800       0.0
# 464111       0.0
# 467731       0.0
# 469172       0.0
#
# [28484 rows x 1 columns]

# %%
# change column name for clarity
sum_gender.rename(columns={"gender":"sum_gender"}, inplace=True)

sum_gender
# Out:
#           sum_gender
# movie_id
# 5                1.0
# 6                0.0
# 11               0.0
# 12               0.0
# 13               0.0
# ...              ...
# 462788           0.0
# 463800           0.0
# 464111           0.0
# 467731           0.0
# 469172           0.0
#
# [28484 rows x 1 columns]

# %%
# create df to total number of people by movie_id
total_gender = sorted_df.groupby(["movie_id"]).count()

total_gender
# Out:
#           department  gender  job  name
# movie_id
# 5                  5       5    5     5
# 6                  1       1    1     1
# 11                 1       1    1     1
# 12                 2       2    2     2
# 13                 2       2    2     2
# ...              ...     ...  ...   ...
# 462788             1       1    1     1
# 463800             1       1    1     1
# 464111             1       1    1     1
# 467731             1       1    1     1
# 469172             1       1    1     1
#
# [28484 rows x 4 columns]

# %%
# Drop all columns but gender column
total_gender.drop(columns=["department","job","name"], inplace=True)

total_gender
# Out:
#           gender
# movie_id
# 5              5
# 6              1
# 11             1
# 12             2
# 13             2
# ...          ...
# 462788         1
# 463800         1
# 464111         1
# 467731         1
# 469172         1
#
# [28484 rows x 1 columns]

# %%
# rename gender column for clarity
total_gender.rename(columns={"gender":"total_gender"}, inplace=True)

total_gender
# Out:
#           total_gender
# movie_id
# 5                    5
# 6                    1
# 11                   1
# 12                   2
# 13                   2
# ...                ...
# 462788               1
# 463800               1
# 464111               1
# 467731               1
# 469172               1
#
# [28484 rows x 1 columns]

# %%
# merge df to have both sum and total aligned
joined_gender = pd.merge(sum_gender, total_gender, how='inner', on='movie_id')

joined_gender
# Out:
#           sum_gender  total_gender
# movie_id
# 5                1.0             5
# 6                0.0             1
# 11               0.0             1
# 12               0.0             2
# 13               0.0             2
# ...              ...           ...
# 462788           0.0             1
# 463800           0.0             1
# 464111           0.0             1
# 467731           0.0             1
# 469172           0.0             1
#
# [28484 rows x 2 columns]

# %%
# add column called "percent_famale" to perform calculation based on sum/total
joined_gender["percent_female"]=(joined_gender["sum_gender"]/joined_gender["total_gender"])

# %%
joined_gender
# Out:
#           sum_gender  total_gender  percent_female
# movie_id
# 5                1.0             5             0.2
# 6                0.0             1             0.0
# 11               0.0             1             0.0
# 12               0.0             2             0.0
# 13               0.0             2             0.0
# ...              ...           ...             ...
# 462788           0.0             1             0.0
# 463800           0.0             1             0.0
# 464111           0.0             1             0.0
# 467731           0.0             1             0.0
# 469172           0.0             1             0.0
#
# [28484 rows x 3 columns]

# %%
# change movie_id to column instead of axis
# solution from https://stackoverflow.com/questions/20461165/how-to-convert-index-of-a-pandas-dataframe-into-a-column
joined_gender=joined_gender.rename_axis("movie_id").reset_index()

# %%
joined_gender.sample(25)
# Out:
#        movie_id  sum_gender  total_gender  percent_female
# 3709      10690         0.0             1        0.000000
# 17228     63579         0.0             1        0.000000
# 16116     55576         0.0             1        0.000000
# 19026     80082         0.0             1        0.000000
# 28326    421725         0.0             1        0.000000
# 13472     43109         0.0             1        0.000000
# 17858     69544         0.0             1        0.000000
# 23868    173893         0.0             1        0.000000
# 3830      10877         1.0             3        0.333333
# 16792     60315         0.0             1        0.000000
# 16149     55734         0.0             1        0.000000
# 19421     83738         0.0             1        0.000000
# 3168       9912         0.0             1        0.000000
# 25389    243442         0.0             1        0.000000
# 13245     42553         0.0             1        0.000000
# 21950    120467         0.0             2        0.000000
# 11718     37265         0.0             1        0.000000
# 20005     88564         0.0             1        0.000000
# 3909      11003         0.0             1        0.000000
# 12210     38909         0.0             1        0.000000
# 8130      23488         0.0             1        0.000000
# 19092     80616         0.0             1        0.000000
# 11431     36215         0.0             1        0.000000
# 27265    334991         0.0             1        0.000000
# 1174       2079         0.0             1        0.000000

# %%
joined_gender.to_csv("Resources/joined_gender_directing.csv", encoding='utf8', index=False)
